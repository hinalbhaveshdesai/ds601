# %% [markdown]
# #### Part-1 NBA Players

# %%
import pandas as pd
import matplotlib.pyplot as plt

nba_players = pd.read_csv('https://raw.githubusercontent.com/msaricaumbc/DS_data/master/all_seasons.csv', index_col = 0)

height = nba_players['player_height']
points = nba_players['pts']

# %%
#plotting heights
plt.hist(height, bins=range(160,240))
plt.title("Heights of NBA players")
# Out:
# Text(0.5, 1.0, 'Heights of NBA players')

# %%
#plotting points
plt.hist(points, bins=range(0,37))
plt.title("Points of NBA Players")
# Out:
# Text(0.5, 1.0, 'Points of NBA Players')

# %%
#plotting heights vs points
plt.scatter(height,points)
plt.xlabel("Height")
plt.ylabel("Points")
plt.title("NBA PLayers Heights vs Points Plot")
# Out:
# Text(0.5, 1.0, 'NBA PLayers Heights vs Points Plot')

# %% [markdown]
# #### Part-2 Bowling

# %%
bowling_data = pd.read_csv("https://raw.githubusercontent.com/msaricaumbc/DS_data/master/bowling_stats.csv",
                            header=None,
                            names=['year','city','state','count1','count2'])
def merge_columns(row):
    if pd.isna(row['count2']):
        return row['count1']
    else:
        return row['count1']*1000+row['count2']
    
bowling_data['total']=bowling_data.apply(merge_columns,axis=1)

year = bowling_data['year']
score = bowling_data['total']

# %%
plt.scatter(score,year)
plt.xlabel("Score")
plt.ylabel("Year")
plt.title("Bowling Data Plot")
# Out:
# Text(0.5, 1.0, 'Bowling Data Plot')
